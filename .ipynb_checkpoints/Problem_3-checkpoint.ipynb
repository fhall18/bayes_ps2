# %% [markdown]
# # Problem 3

# %%
from IPython.core.pylabtools import figsize
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from random import sample
import seaborn as sns
import scipy.stats as ss
from scipy import optimize
from statsmodels.api import OLS # has better summary stats than sklearn's OLSb

# %% [markdown]
# First load the data.

# %%
penguin = pd.read_csv("penguins.csv")
penguin.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %% [markdown]
# ## Part 1

# %%
fl = penguin['flipper_length_mm']
penguin['flipper_length_norm'] = [(i-fl.mean())/fl.std() for i in fl.to_numpy()]
penguin['body_mass_kg'] = penguin['body_mass_g']/1000

print('Normalized flipper data:')
print('\t\tstd:',penguin['flipper_length_norm'].std())
print('\t\tmean:',round(penguin['flipper_length_norm'].mean(),10))
# Out:
# Normalized flipper outcome:
# 		std: 1.0000000000000002
# 		mean: -0.0

# %% [markdown]
# We can check to make sure the distributions look the same.

# %%
plt.figure(figsize=(12.5,10))
ax = plt.subplot(211)
plt.hist(penguin.flipper_length_norm.values, bins =20, label="normalized flippers",color="#467821")
plt.legend(loc="upper right");
ax = plt.subplot(212)
plt.hist(penguin.flipper_length_mm.values,bins = 20,label="non-normalized flippers")
plt.legend(loc="upper right");

# %% [markdown]
# What about the weight distribution of the pandas?

# %%
# curious about weight distribution
plt.figure(figsize=(12.5,10))
# plt.hist(penguin.body_mass_kg.values,label="non-normalized",bins = 50)
sns.distplot(penguin.body_mass_kg.values, label="weight density")
plt.legend(loc="upper right")
plt.show();
# Out:
# /Users/erikweis/opt/anaconda3/envs/datasci/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Part 2
#
# We choose normal priors for $\alpha$ and $\beta$. The prior for $\beta$ has a mean of zero, so as not to impose an effect on the linear regression. For the variance, we choose a log-normal distribution.

# %%
def generate_parameters_prior():
    return [ss.norm(50,np.sqrt(200)).rvs(), # generates alpha
            ss.norm(0,np.sqrt(200)).rvs(),  # generates beta
            ss.lognorm(s=1).rvs()]  # generates var #lognorm.rvs(s=5)

# %%
ss.lognorm

# %%
x = np.linspace(0,200,100)
y = ss.lognorm.pdf(x,s=5)
y2 = ss.lognorm.rvs(s=1,size=100)

# %% [markdown]
# ## Part 3
#
# We can start by creating a funcvtion that samples X.

# %%
def sample_from_x(num_samples):
    return sample(list(penguin['flipper_length_norm']),num_samples)

# %%
def generate_data(alpha, beta, var, X, num_samples=10):
    return ss.norm(alpha + beta * X, np.sqrt(var)).rvs(num_samples)

# %%
# PRIOR PREDICTIVE REGRESSION LINES
for i in range(50):
    params = generate_parameters_prior()
    
    Y0 = generate_data(*params, 0)
    Y1 = generate_data(*params, 1)

    plt.plot([0, 7], [Y0, Y1], c='gray', alpha=0.1)

plt.xlabel('flipper length')
plt.ylabel('penguin weight')
# Out:
# Text(0, 0.5, 'penguin weight')

# %% [markdown]
# ## Part 4

# %%
def log_posterior(alpha, beta, var, Y, X):
    N = len(X)
    if var > 100 or var < 0:
        return -100000000000000000000
    return (-N * np.log(var) / 2 - np.sum((Y - alpha - beta * X) ** 2) / var +     # log_likelihood
        ss.norm(50, np.sqrt(200)).logpdf(alpha) +                           # log of the prior on alpha
        ss.norm(0, np.sqrt(100)).logpdf(beta))                              # log of the prior on beta
            
def minus_log_posterior(theta):
    Y = penguin['body_mass_kg']
    X = penguin['flipper_length_norm']
    return - log_posterior(*theta,Y,X)


fit = optimize.minimize(minus_log_posterior, [50, 0, 10])


# fit approx.
MAP = fit['x']
hess_inv  = fit['hess_inv']
approx = ss.multivariate_normal(MAP, hess_inv)

# %% [markdown]
# ## Part 5

# %%
samples = approx.rvs(1000)

plt.figure(figsize=(12.5,10))
plt.hist(samples[:,1],bins = 20)
plt.ylabel('Distribution')
plt.xlabel(r'$\beta$')
sns.despine()

plt.figure(figsize=(12.5,10))
sns.pairplot(pd.DataFrame(samples, columns=['alpha', 'beta', 'var']))

# %% [markdown]
# ## Part 6

# %%
# data points and regression lines
plt.figure(figsize=(12.5,10))
for i in range(10):  # 10 data sets
    params = approx.rvs()
    alpha = params[0]
    beta = params[1]
    var = params[2]

    Y0 = generate_data(alpha, beta, var, 50)  # simulate 50 measurements at 0
    Y1 = generate_data(alpha, beta, var, 50)  # simulate 50 measurements at 1

    plt.plot([alpha, alpha + beta], c='blue', alpha=0.1, zorder=-100)
    plt.plot([alpha, alpha + beta], c='blue', alpha=0.1, zorder=-100)
   # plt.scatter([0] * 50 + [1] * 50, np.concatenate((Y0, Y1)), c='gray', alpha=0.1, zorder=-100)

plt.xlabel('Flipper Size')
plt.ylabel('Weight')
plt.scatter(penguin['flipper_length_norm'], penguin['body_mass_kg'], s=2, c='red')
